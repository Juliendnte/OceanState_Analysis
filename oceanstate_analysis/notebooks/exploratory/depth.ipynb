# %%
import sys
import os

# %%
sys.path.append(os.path.abspath("../.."))

# %%
from analysis.preprocessing import load_and_clean_depth_data

# %%
df = load_and_clean_depth_data()
df
# Out:
#               time  latitude     depth   longitude  sialb  siage  siconc  ist  \
# 0       2022-06-16     -80.0  0.494025 -180.000000    NaN    NaN     NaN  NaN
# 1       2022-06-16     -80.0  0.494025 -179.916672    NaN    NaN     NaN  NaN
# 2       2022-06-16     -80.0  0.494025 -179.833328    NaN    NaN     NaN  NaN
# 3       2022-06-16     -80.0  0.494025 -179.750000    NaN    NaN     NaN  NaN
# 4       2022-06-16     -80.0  0.494025 -179.666672    NaN    NaN     NaN  NaN
# ...            ...       ...       ...         ...    ...    ...     ...  ...
# 8817115 2022-06-16      90.0  0.494025  179.583344    NaN    NaN     NaN  NaN
# 8817116 2022-06-16      90.0  0.494025  179.666687    NaN    NaN     NaN  NaN
# 8817117 2022-06-16      90.0  0.494025  179.750000    NaN    NaN     NaN  NaN
# 8817118 2022-06-16      90.0  0.494025  179.833344    NaN    NaN     NaN  NaN
# 8817119 2022-06-16      90.0  0.494025  179.916687    NaN    NaN     NaN  NaN
#
#          sivelo  sithick  sisnthick  mlotst  pbo  sob  zos  tob  usi  vsi
# 0           NaN      NaN        NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1           NaN      NaN        NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2           NaN      NaN        NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3           NaN      NaN        NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4           NaN      NaN        NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...         ...      ...        ...     ...  ...  ...  ...  ...  ...  ...
# 8817115     NaN      NaN        NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 8817116     NaN      NaN        NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 8817117     NaN      NaN        NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 8817118     NaN      NaN        NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 8817119     NaN      NaN        NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [8817120 rows x 18 columns]

# %%
df = df[["time", "latitude", "depth", "longitude"]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (12, 6)

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='depth', bins=30)
plt.title('Distribution des profondeurs')
plt.xlabel('Profondeur')
plt.ylabel('Fréquence')
plt.show()

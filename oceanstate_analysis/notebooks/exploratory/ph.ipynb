# %%
import sys
import os

# %%
sys.path.append(os.path.abspath("../.."))

# %%
from analysis.preprocessing import load_and_clean_ph_data
from analysis.plots import plot_ph_evolution

# %%
df_ph = load_and_clean_ph_data()
df_ph
# Out:
#      Entity  Code        Date  pH yearly average      pH
# 0    Hawaii   NaN  1989-11-27           8.109064  8.1101
# 1    Hawaii   NaN  1990-01-05           8.110091  8.1332
# 2    Hawaii   NaN  1990-02-15           8.110729  8.1229
# 3    Hawaii   NaN  1990-03-19           8.110727  8.1340
# 4    Hawaii   NaN  1990-04-13           8.111190  8.1229
# ..      ...   ...         ...                ...     ...
# 334  Hawaii   NaN  1989-06-24                NaN  8.1018
# 335  Hawaii   NaN  1989-07-29                NaN  8.0991
# 336  Hawaii   NaN  1989-08-24                NaN  8.0930
# 337  Hawaii   NaN  1989-09-22                NaN  8.0990
# 338  Hawaii   NaN  1989-10-18                NaN  8.0858
#
# [339 rows x 5 columns]

# %%
df_ph.drop(columns=["Code"], inplace=True)
df_ph
# Out:
#      Entity        Date  pH yearly average      pH
# 0    Hawaii  1989-11-27           8.109064  8.1101
# 1    Hawaii  1990-01-05           8.110091  8.1332
# 2    Hawaii  1990-02-15           8.110729  8.1229
# 3    Hawaii  1990-03-19           8.110727  8.1340
# 4    Hawaii  1990-04-13           8.111190  8.1229
# ..      ...         ...                ...     ...
# 334  Hawaii  1989-06-24                NaN  8.1018
# 335  Hawaii  1989-07-29                NaN  8.0991
# 336  Hawaii  1989-08-24                NaN  8.0930
# 337  Hawaii  1989-09-22                NaN  8.0990
# 338  Hawaii  1989-10-18                NaN  8.0858
#
# [339 rows x 4 columns]

# %%
plot_ph_evolution(df_ph)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\julie\\anaconda3\\envs\\MathDataScience\\lib\\site-packages\\matplotlib\\pyplot.py'>
